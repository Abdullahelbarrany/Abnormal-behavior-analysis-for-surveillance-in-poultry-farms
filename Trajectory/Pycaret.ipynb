# %%
###%pip install pycaret
import pandas as pd
from pycaret.classification import *
import numpy as np

# %%
df = pd.read_csv('allnew.csv')
df['split'] = np.random.randn(df.shape[0], 1)

msk = np.random.rand(len(df)) <= 0.8

train = df[msk]
test = df[~msk]

# %%
train
# Out:
#     Standingstill  Distance Covered      Mean  Max Distance  \
# 0             284        777.750458  0.650293     56.320511
# 1             292        506.526932  0.423518    116.107709
# 2             297         47.719370  0.039899     22.022716
# 3             292        364.973233  0.305162    101.513546
# 4             297        230.639868  0.192843    155.270731
# ..            ...               ...       ...           ...
# 83            253       3152.101020  2.635536    257.670332
# 84            249       3062.026067  2.560222    259.356897
# 86            250       1927.676690  1.611770    188.215302
# 87            252       3176.115669  2.655615    331.965360
# 89            277        873.070575  0.729992    117.957620
#
#     Starting-Ending Pos    Label     split
# 0            672.019345  walking  1.243073
# 1             98.655968    sleep -1.093617
# 2             41.593269    sleep  0.848161
# 3            105.650367    sleep  0.335290
# ...

# %%
# from sklearn.model_selection import train_test_split

# %%
# df3 = pd.read_csv('allnew.csv')
# df3

# %%
# #df = pd.read_csv('out.csv', on_bad_lines='skip')
# df = pd.read_csv('htrain.csv')
# df

# %%
# df2=pd.read_csv('htest.csv')
# df2

# %%
#X_train, X_test, y_train, y_test = train_test_split(df, y, random_state=0, train_size = .80)

# %%
# df2 = pd.read_csv('ss.csv')
# df2

# %%
# df2 = pd.read_csv('a2.csv')
# df2

# %%
train.dtypes
# Out:
# Standingstill            int64
# Distance Covered       float64
# Mean                   float64
# Max Distance           float64
# Starting-Ending Pos    float64
# Label                   object
# split                  float64
# dtype: object

# %%
#features = ['Distance Covered','Mean','Standingstill','Starting-Ending Pos']
#expirement = setup(df3,target='Label',numeric_features=features)
#expirement = setup(X_train,target=y_train)
expirement = setup(train,target='Label')
# Out:
# <style type="text/css">
# #T_3ea58_row9_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_3ea58">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3ea58_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_3ea58_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3ea58_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_3ea58_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_3ea58_row0_col1" class="data row0 col1" >8968</td>
#     </tr>
#     <tr>
#       <th id="T_3ea58_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_3ea58_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_3ea58_row1_col1" class="data row1 col1" >Label</td>
#     </tr>
#     <tr>
#       <th id="T_3ea58_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
l = create_model('lightgbm')
n = create_model('nb')
# Out:
# <style type="text/css">
# #T_44cd8_row10_col0, #T_44cd8_row10_col1, #T_44cd8_row10_col2, #T_44cd8_row10_col3, #T_44cd8_row10_col4, #T_44cd8_row10_col5, #T_44cd8_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_44cd8">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_44cd8_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_44cd8_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_44cd8_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_44cd8_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_44cd8_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_44cd8_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_44cd8_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
# ...

# %%
best_model = compare_models(cross_validation=True)
# Out:
# <style type="text/css">
# #T_2e381 th {
#   text-align: left;
# }
# ...

# %%
predict_model (best_model,test)
# Out:
# <style type="text/css">
# </style>
# <table id="T_15007">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_15007_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_15007_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_15007_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_15007_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_15007_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_15007_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_15007_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_15007_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_15007_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_15007_row0_col0" class="data row0 col0" >SVM - Linear Kernel</td>
# ...

# %%
# z= predict_model (best_model,X_test)
# pred = z.pop('prediction_label')
# pred

# %%
# from sklearn.metrics import accuracy_score
# print('accuracy: %.3f' % accuracy_score(pred,y_test))
