# %%
from ultralytics import YOLO
import cv2


model_path = 'E:/University/Semester 6/Grad/CHICK_t/CHICK_t/April/pose/pose-detection-keypoints-estimation-yolov8-main/pose-detection-keypoints-estimation-yolov8-main/runs/pose/train19\weights/last.pt'

image_path = r'E:\University\Semester 6\Grad\CHICK_t\CHICK_t\April\pose\pose-detection-keypoints-estimation-yolov8-main\pose-detection-keypoints-estimation-yolov8-main\samples\preen.png'
img = cv2.imread(image_path)

model = YOLO(model_path)

results = model(img)[0]

for result in results:
    for keypoint_indx, keypoint in enumerate(result.keypoints.tolist()):
        cv2.putText(img, str(keypoint_indx), (int(keypoint[0]), int(keypoint[1])),
                    cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 2)

cv2.imshow('img', img)
cv2.waitKey(0)

# %%
from ultralytics import YOLO
import cv2
import csv

def pose(frame,model_path):

    

    # image_path = r'E:\University\Semester 6\Grad\CHICK_t\CHICK_t\April\pose\pose-detection-keypoints-estimation-yolov8-main\pose-detection-keypoints-estimation-yolov8-main\samples\1 (5).png'
    # img = cv2.imread(image_path)z

    model = YOLO(model_path)

    results = model(frame)[0]

    for result in results:
        frames_keys = []
        for keypoint_indx, keypoint in enumerate(result.keypoints.tolist()):
            cv2.putText(frame, str(keypoint_indx), (int(keypoint[0]), int(keypoint[1])),
                        cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 2)
            row = (int(keypoint[0]), int(keypoint[1]))
            frames_keys.append(row[0])
            frames_keys.append(row[1])


        with open(r'normal_demo.csv', 'a+') as f:
            writer = csv.writer(f)
            
            writer.writerow(frames_keys)
                
            f.close()



    return frame

# %%
###################################### this main
from ultralytics import YOLO
import cv2
import numpy as np
import os
# f = 4
import csv
comb = []
#best: train16 17 19
folder = r'C:\Users\abdal\Downloads\pose-detection-keypoints-estimation-yolov8-main\frames'
model_path = r'C:\Users\abdal\Downloads\pose-detection-keypoints-estimation-yolov8-main\runs\pose\train17\weights\best.pt'
cap = cv2.VideoCapture(r'C:\Users\abdal\Downloads\pose-detection-keypoints-estimation-yolov8-main\vids\chicken14.mp4')
#cap = cv2.VideoCapture(r'C:\Users\abdal\Downloads\pose-detection-keypoints-estimation-yolov8-main\samples\chicken11.mp4')
ret,frame = cap.read()
h,w,c = frame.shape
model = YOLO(model_path)
diff2= 0
# result = cv2.VideoWriter('filename.avi', 
#                          cv2.VideoWriter_fourcc(*'MJPG'),
#                          10, (w,h))
if (cap.isOpened()== False):
	print("Error opening video file")

while(cap.isOpened()):
	ret, frame = cap.read()
	if not ret:
		break
	results = model(frame)[0]
	for result in results:
		frames_keys = []
		if ret == True:
			
		
			for keypoint_indx, keypoint in enumerate(result.keypoints.tolist()):
				row = (int(keypoint[0]), int(keypoint[1]))
				if len(comb) >= 5:
					diff = (np.subtract(comb[keypoint_indx],row ))
					diff2 = diff[0] + diff[1]
				else:
					comb.append(row)
				if diff2 <=150:

					cv2.putText(frame, str(keypoint_indx), (int(keypoint[0]), int(keypoint[1])),
							cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 2)
					frames_keys.append(row[0])
					frames_keys.append(row[1])

					comb[keypoint_indx] = row
				else:

					cv2.putText(frame, str(keypoint_indx), (comb[keypoint_indx]),
							cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 2)
					frames_keys.append(int(comb[keypoint_indx][0]))
					frames_keys.append(int(comb[keypoint_indx][1]))
				
		
			with open(r'csvs/well8.csv', 'a+') as f:
				writer = csv.writer(f)
				
				writer.writerow(frames_keys)
					
				f.close()
			break
			

		# outpath = os.path.join(folder, f'{f}.jpg')
	
	cv2.imshow('Frame', frame)
	#cv2.imwrite(outpath,frame)
	# f = f+1
	
	# if f == 4:
	# 	result.write(frame)
	# 	f=0
	if cv2.waitKey(25) & 0xFF == ord('q'):
		break




cap.release()
#result.release()

cv2.destroyAllWindows()
# Out:
# 0: 384x640 1 chicken, 207.1ms
# Speed: 2.0ms preprocess, 207.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 chicken, 207.0ms
# Speed: 1.0ms preprocess, 207.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 chicken, 208.4ms
# Speed: 1.0ms preprocess, 208.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 chicken, 205.5ms
# Speed: 1.0ms preprocess, 205.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 chicken, 205.5ms
# Speed: 1.0ms preprocess, 205.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 chicken, 205.0ms
# Speed: 1.0ms preprocess, 205.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 chicken, 206.3ms
# Speed: 1.0ms preprocess, 206.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 chicken, 206.3ms
# ...

# %%
################# main

import cv2
import numpy as np
import os
# f = 4
import csv

#best: train16 17 19
folder = r'C:\Users\abdal\Downloads\pose-detection-keypoints-estimation-yolov8-main\frames'
# model_path = r'C:\Users\abdal\Downloads\pose-detection-keypoints-estimation-yolov8-main\runs\pose\train17\weights\last.pt'
model_path = r'C:\Users\abdal\Downloads\pose-detection-keypoints-estimation-yolov8-main\runs\pose\train17\weights\last.pt'
cap = cv2.VideoCapture(r'C:\Users\abdal\Downloads\pose-detection-keypoints-estimation-yolov8-main\samples\chicken13.mp4')
ret,frame = cap.read()
h,w,c = frame.shape
# result = cv2.VideoWriter('filename.avi', 
#                          cv2.VideoWriter_fourcc(*'MJPG'),
#                          10, (w,h))
if (cap.isOpened()== False):
	print("Error opening video file")

while(cap.isOpened()):
	

	ret, frame = cap.read()
	if ret == True:
		frame = pose(frame,model_path)
		# outpath = os.path.join(folder, f'{f}.jpg')
		cv2.imshow('Frame', frame)
		#cv2.imwrite(outpath,frame)
		# f = f+1
		
		# if f == 4:
		# 	result.write(frame)
		# 	f=0
		if cv2.waitKey(25) & 0xFF == ord('q'):
			break


	else:
		break


cap.release()
#result.release()

cv2.destroyAllWindows()

# %%
import csv
rows = []
with open('wry2test.csv', 'r') as csvfile:

    csvreader = csv.reader(csvfile)
    for row in csvreader:

        rows.append(row)
print((rows[0][0]))

# %%
import csv
rows = []
with open('normal.csv', 'r') as csvfile:

    csvreader = csv.reader(csvfile)
    for row in csvreader:

        rows.append(row)
print(len(rows))

import cv2
import numpy as np
import os
#best: train16
index = 0
frameid = 0
cap = cv2.VideoCapture(r'C:\Users\abdal\Downloads\pose-detection-keypoints-estimation-yolov8-main\samples\chicken11.mp4')
ret,frame = cap.read()
h,w,c = frame.shape

if (cap.isOpened()== False):
	print("Error opening video file")

while(cap.isOpened()):
	

	ret, frame = cap.read()
	if ret == True:
		try:
			for i,x in enumerate (range(0,10,2)):
				cv2.putText(frame, str(i), (int(rows[index][x]), int(rows[index][x+1])), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 2)
			index = index + 1
			cv2.imshow('Frame', frame)
		except:
			break



		if cv2.waitKey(25) & 0xFF == ord('q'):
			break
		frameid = frameid + 1


	else:
		break


cap.release()
cv2.waitKey(30)
# print (index)
cv2.destroyAllWindows()

# %%
y = [(0,0)]
x = [(10,3)]
z = (np.subtract(x, y))
x[0] = z[0]
x[0][0] = 1
print(x[0])
