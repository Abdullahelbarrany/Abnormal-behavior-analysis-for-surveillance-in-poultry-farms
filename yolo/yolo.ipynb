# %%
#!git clone https://github.com/WongKinYiu/yolov7.git
# %cd yolov7
# Out:
# e:\University\Semester 6\Grad\CHICK_t\CHICK_t\yolo\yolov7

# %%
# %pip install -r requirements.txt
# Out:
# ...
#   Using cached torch-1.13.0-cp39-cp39-win_amd64.whl (167.2 MB)
# ...
#   Using cached torchvision-0.14.0-cp39-cp39-win_amd64.whl (1.1 MB)
# ...
#   Using cached thop-0.1.1.post2209072238-py3-none-any.whl (15 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The scripts convert-caffe2-to-onnx.exe, convert-onnx-to-caffe2.exe and torchrun.exe are installed in 'C:\Users\abdal\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# WARNING: You are using pip version 22.0.4; however, version 22.3.1 is available.
# You should consider upgrading via the 'C:\Users\abdal\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip' command.

# %%
import torch
torch.hub.download_url_to_file('https://ultralytics.com/assets/coco2017val.zip', 'tmp.zip')  # download (780M - 5000 images)
# !unzip -q tmp.zip -d ../datasets && rm tmp.zip  # unzip

# %%
# !python train.py --img 640 --batch 2 --epochs 60 --data coco.yaml --weights yolov7.pt --cache --device cpu

# %%
# !python detect.py --weights yolov7-e6e.pt --img 640 --conf 0.25 --source "eating9.mp4" --device 0
# Out:
# Namespace(weights=['yolov7-e6e.pt'], source='eating9.mp4', img_size=640, conf_thres=0.25, iou_thres=0.45, device='0', view_img=False, save_txt=False, save_conf=False, nosave=False, classes=None, agnostic_nms=False, augment=False, update=False, project='runs/detect', name='exp', exist_ok=False, no_trace=False)
# Fusing layers...
#  Convert model to Traced-model...
#  traced_script_module saved!
#  model is traced!
#
# video 1/1 (1/321) e:\University\Semester 6\Grad\CHICK_t\CHICK_t\yolo\yolov7\eating9.mp4: [tensor(359., device='cuda:0'), tensor(227., device='cuda:0'), tensor(415., device='cuda:0'), tensor(281., device='cuda:0')]
# 1 bird, 2 potted plants, Done. (30.9ms) Inference, (39.8ms) NMS
# video 1/1 (2/321) e:\University\Semester 6\Grad\CHICK_t\CHICK_t\yolo\yolov7\eating9.mp4: [tensor(359., device='cuda:0'), tensor(226., device='cuda:0'), tensor(416., device='cuda:0'), tensor(281., device='cuda:0')]
# 1 bird, 1 dog, 2 potted plants, Done. (37.9ms) Inference, (1.0ms) NMS
# ...

# %%
# %cd yolov7
# !python detect.py --weights yolov7-e6e.pt --img 640 --conf 0.25 --source "D:\CS\GRAD\CHICK_t\object_tracking\eating7.mp4"
# Out:
# [WinError 2] The system cannot find the file specified: 'yolov7'
# e:\University\Semester 6\Grad\CHICK_t\CHICK_t\yolo\yolov7
# Namespace(weights=['yolov7-e6e.pt'], source='D:\\CS\\GRAD\\CHICK_t\\object_tracking\\eating7.mp4', img_size=640, conf_thres=0.25, iou_thres=0.45, device='', view_img=False, save_txt=False, save_conf=False, nosave=False, classes=None, agnostic_nms=False, augment=False, update=False, project='runs/detect', name='exp', exist_ok=False, no_trace=False)
# Fusing layers...
#  Convert model to Traced-model...
#  traced_script_module saved!
#  model is traced!
# YOLOR  2022-12-2 torch 1.13.0+cpu CPU
#
# Model Summary: 792 layers, 151687420 parameters, 817020 gradients
# Traceback (most recent call last):
#   File "e:\University\Semester 6\Grad\CHICK_t\CHICK_t\yolo\yolov7\detect.py", line 196, in <module>
#     detect()
#   File "e:\University\Semester 6\Grad\CHICK_t\CHICK_t\yolo\yolov7\detect.py", line 57, in detect
# ...

# %%
import torch
torch.cuda.is_available()
# Out:
# True
