# %%
import os
import numpy as np
import tensorflow as tf
from tensorflow import keras
from keras import layers, utils, models, callbacks as cb

# %%
image_size = (1000,1000)
batch_size = 1

train_ds = tf.keras.preprocessing.image_dataset_from_directory(
    "training",
    validation_split=0.2,
    subset="training",
    seed=1337,
    image_size=image_size,
    batch_size=batch_size,
)
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
    "validation",
    validation_split=0.8,
    subset="validation",
    seed=1337,
    image_size=image_size,
    batch_size=batch_size,
)
train_ds = train_ds.prefetch(buffer_size=10)
val_ds = val_ds.prefetch(buffer_size=10)
print(f"{type(train_ds)}")
# Out:
# Found 72 files belonging to 3 classes.
# Using 58 files for training.
# Found 18 files belonging to 3 classes.
# Using 14 files for validation.
# <class 'tensorflow.python.data.ops.dataset_ops.PrefetchDataset'>

# %%
# import matplotlib.pyplot as plt

# plt.figure(figsize=(25, 45))
# for images, labels in train_ds.take(1):
#     for i in range(9):
#         ax = plt.subplot(3, 3, i + 1)
#         plt.imshow(images[i].numpy().astype("uint8"))
#         plt.title(int(labels[i]))
#         plt.axis("off")

# %%
def make_model(input_shape, num_classes):
    return keras.Sequential(
    [
        keras.Input(shape=input_shape),
        layers.RandomFlip("horizontal"),
        layers.RandomRotation(0.2),
        layers.Conv2D(32, kernel_size=(3, 3), activation="relu"),
        layers.MaxPooling2D(pool_size=(2, 2)),
        layers.Conv2D(64, kernel_size=(3, 3), activation="relu"),
        layers.MaxPooling2D(pool_size=(2, 2)),
        layers.Flatten(),
        layers.Dropout(0.7),
        layers.Dense(num_classes, activation="softmax"),
    ]
    )


model = make_model(input_shape=image_size + (3,), num_classes=3)

# %%
epochs = 100

callbacks = [
    keras.callbacks.ModelCheckpoint("save_at_{epoch}.h5"),
    keras.callbacks.TensorBoard(log_dir="./logs")
]

model.compile(
    optimizer="adam",
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"],
)
model.fit(
    train_ds, epochs=epochs, callbacks=callbacks,validation_data = val_ds,use_multiprocessing=True,
)
model.save('chicken.h5')
# Out:
# Epoch 1/100
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# 58/58 [==============================] - 6s 57ms/step - loss: 4759.8027 - accuracy: 0.2241 - val_loss: 15.7021 - val_accuracy: 0.0714
# Epoch 2/100
# 58/58 [==============================] - 3s 58ms/step - loss: 8.9757 - accuracy: 0.3966 - val_loss: 3.0435 - val_accuracy: 0.3571
# Epoch 3/100
# 58/58 [==============================] - 4s 68ms/step - loss: 2.1993 - accuracy: 0.4655 - val_loss: 2.0662 - val_accuracy: 0.3571
# Epoch 4/100
# 58/58 [==============================] - 4s 66ms/step - loss: 2.5834 - accuracy: 0.3793 - val_loss: 1.5394 - val_accuracy: 0.1429
# Epoch 5/100
# 58/58 [==============================] - 4s 74ms/step - loss: 1.1187 - accuracy: 0.5517 - val_loss: 1.3613 - val_accuracy: 0.5000
# Epoch 6/100
# 58/58 [==============================] - 4s 71ms/step - loss: 1.1488 - accuracy: 0.4483 - val_loss: 1.1087 - val_accuracy: 0.4286
# Epoch 7/100
# 58/58 [==============================] - 3s 54ms/step - loss: 1.0654 - accuracy: 0.4655 - val_loss: 1.2882 - val_accuracy: 0.3571
# Epoch 8/100
# 58/58 [==============================] - 4s 63ms/step - loss: 0.9605 - accuracy: 0.6379 - val_loss: 1.2965 - val_accuracy: 0.3571
# Epoch 9/100
# 58/58 [==============================] - 4s 71ms/step - loss: 1.0552 - accuracy: 0.5517 - val_loss: 1.2262 - val_accuracy: 0.5714
# Epoch 10/100
# 58/58 [==============================] - 4s 68ms/step - loss: 0.9766 - accuracy: 0.5690 - val_loss: 1.2507 - val_accuracy: 0.4286
# Epoch 11/100
# 58/58 [==============================] - 5s 79ms/step - loss: 0.9798 - accuracy: 0.6034 - val_loss: 1.1796 - val_accuracy: 0.4286
# Epoch 12/100
# 58/58 [==============================] - 4s 63ms/step - loss: 0.9776 - accuracy: 0.5862 - val_loss: 0.9761 - val_accuracy: 0.4286
# Epoch 13/100
# 58/58 [==============================] - 4s 67ms/step - loss: 1.1513 - accuracy: 0.4655 - val_loss: 0.9489 - val_accuracy: 0.4286
# Epoch 14/100
# 58/58 [==============================] - 5s 80ms/step - loss: 0.9679 - accuracy: 0.5517 - val_loss: 1.1361 - val_accuracy: 0.4286
# Epoch 15/100
# 58/58 [==============================] - 4s 68ms/step - loss: 1.0803 - accuracy: 0.5172 - val_loss: 1.0093 - val_accuracy: 0.4286
# Epoch 16/100
# 58/58 [==============================] - 4s 62ms/step - loss: 1.0749 - accuracy: 0.4828 - val_loss: 0.9714 - val_accuracy: 0.5714
# Epoch 17/100
# 58/58 [==============================] - 4s 64ms/step - loss: 1.0359 - accuracy: 0.4828 - val_loss: 0.9218 - val_accuracy: 0.5000
# Epoch 18/100
# 58/58 [==============================] - 5s 79ms/step - loss: 0.9736 - accuracy: 0.6034 - val_loss: 0.9075 - val_accuracy: 0.4286
# Epoch 19/100
# 58/58 [==============================] - 4s 72ms/step - loss: 1.0848 - accuracy: 0.4483 - val_loss: 0.9740 - val_accuracy: 0.6429
# Epoch 20/100
# 58/58 [==============================] - 3s 54ms/step - loss: 1.0383 - accuracy: 0.5172 - val_loss: 0.9904 - val_accuracy: 0.6429
# Epoch 21/100
# 58/58 [==============================] - 4s 68ms/step - loss: 1.0823 - accuracy: 0.5172 - val_loss: 1.0972 - val_accuracy: 0.3571
# Epoch 22/100
# 58/58 [==============================] - 4s 68ms/step - loss: 1.0286 - accuracy: 0.5345 - val_loss: 1.0793 - val_accuracy: 0.4286
# Epoch 23/100
# 58/58 [==============================] - 4s 69ms/step - loss: 0.9926 - accuracy: 0.5172 - val_loss: 1.1868 - val_accuracy: 0.5000
# Epoch 24/100
# 58/58 [==============================] - 4s 64ms/step - loss: 1.1823 - accuracy: 0.4655 - val_loss: 1.0532 - val_accuracy: 0.5714
# Epoch 25/100
# 58/58 [==============================] - 4s 74ms/step - loss: 1.0953 - accuracy: 0.4310 - val_loss: 1.0997 - val_accuracy: 0.5000
# Epoch 26/100
# 58/58 [==============================] - 4s 70ms/step - loss: 1.1353 - accuracy: 0.3448 - val_loss: 1.0036 - val_accuracy: 0.7143
# Epoch 27/100
# 58/58 [==============================] - 4s 74ms/step - loss: 1.2297 - accuracy: 0.3966 - val_loss: 0.9099 - val_accuracy: 0.7143
# Epoch 28/100
# 58/58 [==============================] - 4s 63ms/step - loss: 1.0711 - accuracy: 0.5000 - val_loss: 0.9332 - val_accuracy: 0.6429
# Epoch 29/100
# 58/58 [==============================] - 4s 61ms/step - loss: 1.1226 - accuracy: 0.4828 - val_loss: 0.9479 - val_accuracy: 0.5714
# Epoch 30/100
# 58/58 [==============================] - 4s 64ms/step - loss: 1.0658 - accuracy: 0.4138 - val_loss: 1.0158 - val_accuracy: 0.6429
# Epoch 31/100
# 58/58 [==============================] - 4s 64ms/step - loss: 1.1221 - accuracy: 0.3966 - val_loss: 1.0259 - val_accuracy: 0.5714
# Epoch 32/100
# 58/58 [==============================] - 4s 69ms/step - loss: 1.1221 - accuracy: 0.3448 - val_loss: 1.0090 - val_accuracy: 0.6429
# Epoch 33/100
# 58/58 [==============================] - 3s 59ms/step - loss: 1.0693 - accuracy: 0.4655 - val_loss: 1.0286 - val_accuracy: 0.5000
# Epoch 34/100
# 58/58 [==============================] - 4s 61ms/step - loss: 1.0873 - accuracy: 0.4310 - val_loss: 1.0177 - val_accuracy: 0.6429
# Epoch 35/100
# 58/58 [==============================] - 4s 67ms/step - loss: 1.0615 - accuracy: 0.5172 - val_loss: 1.0386 - val_accuracy: 0.5714
# Epoch 36/100
# 58/58 [==============================] - 4s 68ms/step - loss: 1.1265 - accuracy: 0.3448 - val_loss: 1.0598 - val_accuracy: 0.6429
# Epoch 37/100
# 58/58 [==============================] - 5s 82ms/step - loss: 1.0794 - accuracy: 0.4138 - val_loss: 1.0618 - val_accuracy: 0.5714
# Epoch 38/100
# 58/58 [==============================] - 5s 89ms/step - loss: 1.0536 - accuracy: 0.5000 - val_loss: 1.0434 - val_accuracy: 0.6429
# Epoch 39/100
# 58/58 [==============================] - 4s 68ms/step - loss: 1.1969 - accuracy: 0.4483 - val_loss: 1.0667 - val_accuracy: 0.5000
# Epoch 40/100
# 58/58 [==============================] - 3s 53ms/step - loss: 1.0553 - accuracy: 0.4655 - val_loss: 1.0527 - val_accuracy: 0.5714
# Epoch 41/100
# 58/58 [==============================] - 4s 61ms/step - loss: 1.1121 - accuracy: 0.4483 - val_loss: 1.0975 - val_accuracy: 0.5714
# Epoch 42/100
# 58/58 [==============================] - 4s 71ms/step - loss: 1.1065 - accuracy: 0.3621 - val_loss: 1.0802 - val_accuracy: 0.4286
# Epoch 43/100
# 58/58 [==============================] - 4s 72ms/step - loss: 1.1050 - accuracy: 0.3793 - val_loss: 1.0821 - val_accuracy: 0.4286
# Epoch 44/100
# 58/58 [==============================] - 4s 69ms/step - loss: 1.1032 - accuracy: 0.3448 - val_loss: 1.0832 - val_accuracy: 0.4286
# Epoch 45/100
# 58/58 [==============================] - 4s 73ms/step - loss: 1.1017 - accuracy: 0.3621 - val_loss: 1.0831 - val_accuracy: 0.4286
# Epoch 46/100
# 58/58 [==============================] - 4s 64ms/step - loss: 1.1054 - accuracy: 0.3276 - val_loss: 1.0872 - val_accuracy: 0.4286
# Epoch 47/100
# 58/58 [==============================] - 3s 54ms/step - loss: 1.1051 - accuracy: 0.3276 - val_loss: 1.0950 - val_accuracy: 0.4286
# Epoch 48/100
# 58/58 [==============================] - 4s 65ms/step - loss: 1.0858 - accuracy: 0.4310 - val_loss: 1.0858 - val_accuracy: 0.4286
# Epoch 49/100
# 58/58 [==============================] - 3s 53ms/step - loss: 1.0930 - accuracy: 0.3793 - val_loss: 1.0894 - val_accuracy: 0.4286
# Epoch 50/100
# 58/58 [==============================] - 4s 66ms/step - loss: 1.0458 - accuracy: 0.5000 - val_loss: 1.3752 - val_accuracy: 0.4286
# Epoch 51/100
# 58/58 [==============================] - 4s 67ms/step - loss: 1.0986 - accuracy: 0.5517 - val_loss: 1.1578 - val_accuracy: 0.5714
# Epoch 52/100
# 58/58 [==============================] - 4s 71ms/step - loss: 1.1368 - accuracy: 0.5345 - val_loss: 1.1071 - val_accuracy: 0.5000
# Epoch 53/100
# 58/58 [==============================] - 4s 63ms/step - loss: 1.0625 - accuracy: 0.5517 - val_loss: 1.1148 - val_accuracy: 0.5000
# Epoch 54/100
# 58/58 [==============================] - 5s 81ms/step - loss: 1.0451 - accuracy: 0.4828 - val_loss: 1.1292 - val_accuracy: 0.4286
# Epoch 55/100
# 58/58 [==============================] - 4s 69ms/step - loss: 1.1706 - accuracy: 0.4828 - val_loss: 1.1233 - val_accuracy: 0.5000
# Epoch 56/100
# 58/58 [==============================] - 6s 107ms/step - loss: 1.1418 - accuracy: 0.3448 - val_loss: 1.0796 - val_accuracy: 0.4286
# Epoch 57/100
# 58/58 [==============================] - 11s 196ms/step - loss: 1.1403 - accuracy: 0.4828 - val_loss: 1.1086 - val_accuracy: 0.4286
# Epoch 58/100
# 58/58 [==============================] - 13s 228ms/step - loss: 1.1262 - accuracy: 0.3621 - val_loss: 1.0967 - val_accuracy: 0.4286
# Epoch 59/100
# 58/58 [==============================] - 5s 78ms/step - loss: 1.1037 - accuracy: 0.3448 - val_loss: 1.0956 - val_accuracy: 0.4286
# Epoch 60/100
# 58/58 [==============================] - 6s 110ms/step - loss: 1.1028 - accuracy: 0.3448 - val_loss: 1.0949 - val_accuracy: 0.4286
# Epoch 61/100
# 32/58 [===============>..............] - ETA: 1s - loss: 1.1180 - accuracy: 0.3125
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# e:\University\Semester 6\Grad\CHICK_t\CHICK_t\April\June New\traj 10 se\main.ipynb Cell 5 in <cell line: 13>()
#       <a href='vscode-notebook-cell:/e%3A/University/Semester%206/Grad/CHICK_t/CHICK_t/April/June%20New/traj%2010%20se/main.ipynb#W4sZmlsZQ%3D%3D?line=2'>3</a> callbacks = [
#       <a href='vscode-notebook-cell:/e%3A/University/Semester%206/Grad/CHICK_t/CHICK_t/April/June%20New/traj%2010%20se/main.ipynb#W4sZmlsZQ%3D%3D?line=3'>4</a>     keras.callbacks.ModelCheckpoint("save_at_{epoch}.h5"),
#       <a href='vscode-notebook-cell:/e%3A/University/Semester%206/Grad/CHICK_t/CHICK_t/April/June%20New/traj%2010%20se/main.ipynb#W4sZmlsZQ%3D%3D?line=4'>5</a>     keras.callbacks.TensorBoard(log_dir="./logs")
#       <a href='vscode-notebook-cell:/e%3A/University/Semester%206/Grad/CHICK_t/CHICK_t/April/June%20New/traj%2010%20se/main.ipynb#W4sZmlsZQ%3D%3D?line=5'>6</a> ]
#       <a href='vscode-notebook-cell:/e%3A/University/Semester%206/Grad/CHICK_t/CHICK_t/April/June%20New/traj%2010%20se/main.ipynb#W4sZmlsZQ%3D%3D?line=7'>8</a> model.compile(
#       <a href='vscode-notebook-cell:/e%3A/University/Semester%206/Grad/CHICK_t/CHICK_t/April/June%20New/traj%2010%20se/main.ipynb#W4sZmlsZQ%3D%3D?line=8'>9</a>     optimizer="adam",
#      <a href='vscode-notebook-cell:/e%3A/University/Semester%206/Grad/CHICK_t/CHICK_t/April/June%20New/traj%2010%20se/main.ipynb#W4sZmlsZQ%3D%3D?line=9'>10</a>     loss="sparse_categorical_crossentropy",
#      <a href='vscode-notebook-cell:/e%3A/University/Semester%206/Grad/CHICK_t/CHICK_t/April/June%20New/traj%2010%20se/main.ipynb#W4sZmlsZQ%3D%3D?line=10'>11</a>     metrics=["accuracy"],
#      <a href='vscode-notebook-cell:/e%3A/University/Semester%206/Grad/CHICK_t/CHICK_t/April/June%20New/traj%2010%20se/main.ipynb#W4sZmlsZQ%3D%3D?line=11'>12</a> )
# ---> <a href='vscode-notebook-cell:/e%3A/University/Semester%206/Grad/CHICK_t/CHICK_t/April/June%20New/traj%2010%20se/main.ipynb#W4sZmlsZQ%3D%3D?line=12'>13</a> model.fit(
#      <a href='vscode-notebook-cell:/e%3A/University/Semester%206/Grad/CHICK_t/CHICK_t/April/June%20New/traj%2010%20se/main.ipynb#W4sZmlsZQ%3D%3D?line=13'>14</a>     train_ds, epochs=epochs, callbacks=callbacks,validation_data = val_ds,use_multiprocessing=True,
#      <a href='vscode-notebook-cell:/e%3A/University/Semester%206/Grad/CHICK_t/CHICK_t/April/June%20New/traj%2010%20se/main.ipynb#W4sZmlsZQ%3D%3D?line=14'>15</a> )
#      <a href='vscode-notebook-cell:/e%3A/University/Semester%206/Grad/CHICK_t/CHICK_t/April/June%20New/traj%2010%20se/main.ipynb#W4sZmlsZQ%3D%3D?line=15'>16</a> model.save('chicken.h5')
#
# File c:\Users\abdal\miniconda3\envs\tf\lib\site-packages\keras\utils\traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\abdal\miniconda3\envs\tf\lib\site-packages\keras\engine\training.py:1570, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1568 logs = tmp_logs
#    1569 end_step = step + data_handler.step_increment
# -> 1570 callbacks.on_train_batch_end(end_step, logs)
#    1571 if self.stop_training:
#    1572     break
#
# File c:\Users\abdal\miniconda3\envs\tf\lib\site-packages\keras\callbacks.py:470, in CallbackList.on_train_batch_end(self, batch, logs)
#     463 """Calls the `on_train_batch_end` methods of its callbacks.
#     464
#     465 Args:
#     466     batch: Integer, index of batch within the current epoch.
#     467     logs: Dict. Aggregated metric results up until this batch.
#     468 """
#     469 if self._should_call_train_batch_hooks:
# --> 470     self._call_batch_hook(ModeKeys.TRAIN, "end", batch, logs=logs)
#
# File c:\Users\abdal\miniconda3\envs\tf\lib\site-packages\keras\callbacks.py:317, in CallbackList._call_batch_hook(self, mode, hook, batch, logs)
#     315     self._call_batch_begin_hook(mode, batch, logs)
#     316 elif hook == "end":
# --> 317     self._call_batch_end_hook(mode, batch, logs)
#     318 else:
#     319     raise ValueError(
#     320         f"Unrecognized hook: {hook}. "
#     321         'Expected values are ["begin", "end"]'
#     322     )
#
# File c:\Users\abdal\miniconda3\envs\tf\lib\site-packages\keras\callbacks.py:340, in CallbackList._call_batch_end_hook(self, mode, batch, logs)
#     337     batch_time = time.time() - self._batch_start_time
#     338     self._batch_times.append(batch_time)
# --> 340 self._call_batch_hook_helper(hook_name, batch, logs)
#     342 if len(self._batch_times) >= self._num_batches_for_timing_check:
#     343     end_hook_name = hook_name
#
# File c:\Users\abdal\miniconda3\envs\tf\lib\site-packages\keras\callbacks.py:388, in CallbackList._call_batch_hook_helper(self, hook_name, batch, logs)
#     386 for callback in self.callbacks:
#     387     hook = getattr(callback, hook_name)
# --> 388     hook(batch, logs)
#     390 if self._check_timing:
#     391     if hook_name not in self._hook_times:
#
# File c:\Users\abdal\miniconda3\envs\tf\lib\site-packages\keras\callbacks.py:1081, in ProgbarLogger.on_train_batch_end(self, batch, logs)
#    1080 def on_train_batch_end(self, batch, logs=None):
# -> 1081     self._batch_update_progbar(batch, logs)
#
# File c:\Users\abdal\miniconda3\envs\tf\lib\site-packages\keras\callbacks.py:1157, in ProgbarLogger._batch_update_progbar(self, batch, logs)
#    1153     self.seen += add_seen
#    1155 if self.verbose == 1:
#    1156     # Only block async when verbose = 1.
# -> 1157     logs = tf_utils.sync_to_numpy_or_python_type(logs)
#    1158     self.progbar.update(self.seen, list(logs.items()), finalize=False)
#
# File c:\Users\abdal\miniconda3\envs\tf\lib\site-packages\keras\utils\tf_utils.py:635, in sync_to_numpy_or_python_type(tensors)
#     632         return t
#     633     return t.item() if np.ndim(t) == 0 else t
# --> 635 return tf.nest.map_structure(_to_single_numpy_or_python_type, tensors)
#
# File c:\Users\abdal\miniconda3\envs\tf\lib\site-packages\tensorflow\python\util\nest.py:917, in map_structure(func, *structure, **kwargs)
#     913 flat_structure = (flatten(s, expand_composites) for s in structure)
#     914 entries = zip(*flat_structure)
#     916 return pack_sequence_as(
# --> 917     structure[0], [func(*x) for x in entries],
#     918     expand_composites=expand_composites)
#
# File c:\Users\abdal\miniconda3\envs\tf\lib\site-packages\tensorflow\python\util\nest.py:917, in <listcomp>(.0)
#     913 flat_structure = (flatten(s, expand_composites) for s in structure)
#     914 entries = zip(*flat_structure)
#     916 return pack_sequence_as(
# --> 917     structure[0], [func(*x) for x in entries],
#     918     expand_composites=expand_composites)
#
# File c:\Users\abdal\miniconda3\envs\tf\lib\site-packages\keras\utils\tf_utils.py:628, in sync_to_numpy_or_python_type.<locals>._to_single_numpy_or_python_type(t)
#     625 def _to_single_numpy_or_python_type(t):
#     626     # Don't turn ragged or sparse tensors to NumPy.
#     627     if isinstance(t, tf.Tensor):
# --> 628         t = t.numpy()
#     629     # Strings, ragged and sparse tensors don't have .item(). Return them
#     630     # as-is.
#     631     if not isinstance(t, (np.ndarray, np.generic)):
#
# File c:\Users\abdal\miniconda3\envs\tf\lib\site-packages\tensorflow\python\framework\ops.py:1157, in _EagerTensorBase.numpy(self)
#    1134 """Copy of the contents of this Tensor into a NumPy array or scalar.
#    1135
#    1136 Unlike NumPy arrays, Tensors are immutable, so this method has to copy
#    (...)
#    1154     NumPy dtype.
#    1155 """
#    1156 # TODO(slebedev): Consider avoiding a copy for non-CPU or remote tensors.
# -> 1157 maybe_arr = self._numpy()  # pylint: disable=protected-access
#    1158 return maybe_arr.copy() if isinstance(maybe_arr, np.ndarray) else maybe_arr
#
# File c:\Users\abdal\miniconda3\envs\tf\lib\site-packages\tensorflow\python\framework\ops.py:1123, in _EagerTensorBase._numpy(self)
#    1121 def _numpy(self):
#    1122   try:
# -> 1123     return self._numpy_internal()
#    1124   except core._NotOkStatusException as e:  # pylint: disable=protected-access
#    1125     raise core._status_to_exception(e) from None
#
# KeyboardInterrupt:

# %%
import tensorflow as tf
tf.version.VERSION
# Out:
# '2.10.1'
